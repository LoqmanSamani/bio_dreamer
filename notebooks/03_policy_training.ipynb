# %% [markdown]
# # 03 — Policy Training & Dreaming
#
# **Purpose:** Train the actor-critic policy inside the world model and visualise dreaming rollouts.
#
# ## Sections
#
# ### 1. Load Trained World Model
# - Load world model checkpoint from notebook 02 or scripts/
# - Freeze world model weights
# - Verify dream rollouts work
#
# ### 2. Policy Instantiation
# - Choose policy type: PPO, SAC, MCTS, ActiveInference
# - Initialise actor and critic networks
# - Print architecture summary
#
# ### 3. Imagination-Based Training
# - Run PolicyTrainer with live reward curve plotting
# - Visualise: mean return vs. epoch, actor/critic loss, entropy bonus
# - Monitor mutation diversity across dreamed episodes
#
# ### 4. Dream Visualisation
# - Run policy in the world model (no real environment)
# - Plot fitness trajectory over dreaming steps
# - Show mutation sequence (what mutations the policy proposes)
# - 3-D structure viewer for top-ranked candidate (if ProteinDreamer)
#
# ### 5. Candidate Ranking
# - Apply CandidateRanker with DPP diversity selection
# - Display Pareto front for multi-objective designs
# - Export top candidates to CSV
